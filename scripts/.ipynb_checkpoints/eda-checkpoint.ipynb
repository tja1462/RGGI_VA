# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
plant_data = pd.read_csv('../data/final_dataset.csv')
plant_data
# Out:
#      ORISPL  YEAR PSTATABB  NAMEPCAP  CAPFAC            SECTOR PLFUELCT  \
# 0     55279  2020       IL    1086.2  0.0808       IPP Non-CHP      GAS
# 1     55296  2020       IL     312.8  0.0053       IPP Non-CHP      GAS
# 2     55188  2020       IL     611.2  0.3719       IPP Non-CHP      GAS
# 3     55253  2020       IL     356.0  0.0122       IPP Non-CHP      GAS
# 4     55438  2020       IL     540.0  0.0800       IPP Non-CHP      GAS
# ..      ...   ...      ...       ...     ...               ...      ...
# 847    3948  2021       WV    1632.6  0.3335  Electric Utility     COAL
# 848    3954  2021       WV    1680.9  0.3741  Electric Utility     COAL
# 849    6264  2021       WV    1300.0  0.6263  Electric Utility     COAL
# 850   55349  2021       WV     344.0  0.4156       IPP Non-CHP      GAS
# 851    6004  2021       WV    1368.0  0.6328       IPP Non-CHP     COAL
#
#       PLNGENAN     PLHTIAN    PLCO2AN  PLCO2RTA  TREATED  NEIGHBOR  POST
# ...

# %%
plant_data.describe()
# Out:
#              ORISPL         YEAR     NAMEPCAP      CAPFAC      PLNGENAN  \
# count    852.000000   852.000000   852.000000  852.000000  8.520000e+02
# mean   30521.915493  2020.433099   690.115023    0.256942  2.021913e+06
# std    25689.993570     1.717124   631.325974    0.268452  2.994570e+06
# min       54.000000  2018.000000    25.000000    0.000000 -5.759600e+04
# 25%     3799.000000  2019.000000   126.600000    0.021325  5.371550e+04
# 50%    50481.000000  2020.000000   557.300000    0.121700  4.570030e+05
# 75%    55297.000000  2022.000000  1067.675000    0.499675  3.505229e+06
# max    63931.000000  2023.000000  2932.600000    0.872100  1.600620e+07
#
#             PLHTIAN       PLCO2AN       PLCO2RTA     TREATED    NEIGHBOR  \
# count  8.520000e+02  8.520000e+02     852.000000  852.000000  852.000000
# mean   1.788269e+07  1.473947e+06    1773.645062    0.241784    0.147887
# std    2.689300e+07  2.565978e+06    4781.255351    0.428416    0.355197
# ...

# %%
treat_0 = plant_data.loc[plant_data["TREATED"] == 0].describe()
treat_1 = plant_data.loc[plant_data["TREATED"] == 1].describe()

treat_0
# Out:
#              ORISPL         YEAR     NAMEPCAP      CAPFAC      PLNGENAN  \
# count    646.000000   646.000000   646.000000  646.000000  6.460000e+02
# mean   30549.554180  2020.436533   711.320588    0.263228  2.127461e+06
# std    25992.879913     1.715817   662.836881    0.272168  3.087603e+06
# min       54.000000  2018.000000    25.000000    0.000000 -5.759600e+04
# 25%     2917.000000  2019.000000   115.500000    0.021225  5.080575e+04
# 50%    50481.000000  2020.000000   571.800000    0.127050  4.634890e+05
# 75%    55296.000000  2022.000000  1150.000000    0.517300  3.930108e+06
# max    63931.000000  2023.000000  2932.600000    0.842700  1.600620e+07
#
#             PLHTIAN       PLCO2AN       PLCO2RTA  TREATED    NEIGHBOR  \
# count  6.460000e+02  6.460000e+02     646.000000    646.0  646.000000
# mean   1.944155e+07  1.682216e+06    1879.137478      0.0    0.195046
# std    2.884873e+07  2.842847e+06    5465.635200      0.0    0.396543
# ...

# %%
treat_1
# Out:
#              ORISPL         YEAR     NAMEPCAP      CAPFAC      PLNGENAN  \
# count    206.000000   206.000000   206.000000  206.000000  2.060000e+02
# mean   30435.242718  2020.422330   623.616019    0.237230  1.690922e+06
# std    24777.656537     1.725359   516.088605    0.256090  2.661892e+06
# min     3775.000000  2018.000000    27.000000    0.000000  0.000000e+00
# 25%     7032.000000  2019.000000   254.200000    0.021575  5.719725e+04
# 50%    10633.000000  2020.000000   475.000000    0.110600  4.266650e+05
# 75%    55381.000000  2022.000000   848.000000    0.446125  2.385013e+06
# max    59913.000000  2023.000000  2081.900000    0.872100  1.151319e+07
#
#             PLHTIAN       PLCO2AN     PLCO2RTA  TREATED  NEIGHBOR        POST
# count  2.060000e+02  2.060000e+02   206.000000    206.0     206.0  206.000000
# mean   1.299421e+07  8.208314e+05  1442.829039      1.0       0.0    0.480583
# std    1.876404e+07  1.157272e+06   873.109619      0.0       0.0    0.500840
# ...

# %%
post_0 = plant_data.loc[plant_data["POST"] == 0].describe()
post_1 = plant_data.loc[plant_data["POST"] == 1].describe()

post_0
# Out:
#              ORISPL         YEAR     NAMEPCAP      CAPFAC      PLNGENAN  \
# count    440.000000   440.000000   440.000000  440.000000  4.400000e+02
# mean   29495.947727  2018.972727   702.824091    0.244157  1.928073e+06
# std    25580.005450     0.817899   654.918900    0.269359  2.997922e+06
# min       54.000000  2018.000000    26.100000    0.000000 -5.759600e+04
# 25%     3796.000000  2018.000000   125.700000    0.017700  4.187575e+04
# 50%    10633.000000  2019.000000   555.600000    0.092350  3.734475e+05
# 75%    55284.000000  2020.000000  1088.850000    0.476200  3.206499e+06
# max    60376.000000  2020.000000  2932.600000    0.872100  1.600620e+07
#
#             PLHTIAN       PLCO2AN      PLCO2RTA     TREATED    NEIGHBOR   POST
# count  4.400000e+02  4.400000e+02    440.000000  440.000000  440.000000  440.0
# mean   1.713003e+07  1.427271e+06   1608.267995    0.243182    0.150000    0.0
# std    2.703670e+07  2.593430e+06   1249.071399    0.429492    0.357478    0.0
# ...

# %%
post_1
# Out:
#              ORISPL         YEAR     NAMEPCAP      CAPFAC      PLNGENAN  \
# count    412.000000   412.000000   412.000000  412.000000  4.120000e+02
# mean   31617.609223  2021.992718   676.542233    0.270595  2.122129e+06
# std    25792.915018     0.817953   605.616213    0.267131  2.991374e+06
# min       54.000000  2021.000000    25.000000    0.000000  0.000000e+00
# 25%     3803.000000  2021.000000   126.600000    0.028275  6.173975e+04
# 50%    52019.000000  2022.000000   559.000000    0.160900  5.426465e+05
# 75%    55350.000000  2023.000000  1061.500000    0.514825  3.641665e+06
# max    63931.000000  2023.000000  2932.600000    0.842700  1.380673e+07
#
#             PLHTIAN       PLCO2AN       PLCO2RTA     TREATED    NEIGHBOR  \
# count  4.120000e+02  4.120000e+02     412.000000  412.000000  412.000000
# mean   1.868650e+07  1.523795e+06    1950.261347    0.240291    0.145631
# std    2.674812e+07  2.538534e+06    6753.281356    0.427780    0.353165
# ...

# %%
## Correlation Matrix
corr_matrix = plant_data[['NAMEPCAP','CAPFAC','PLNGENAN','PLHTIAN', 'PLCO2AN', 'PLCO2RTA']].corr()
plt.figure()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix')
plt.savefig('../figures/correlation_matrix.png')
plt.show()

# %%
plant_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ORISPL    852 non-null    int64
#  1   YEAR      852 non-null    int64
#  2   PSTATABB  852 non-null    object
#  3   NAMEPCAP  852 non-null    float64
#  4   CAPFAC    852 non-null    float64
#  5   SECTOR    852 non-null    object
#  6   PLFUELCT  852 non-null    object
#  7   PLNGENAN  852 non-null    float64
#  8   PLHTIAN   852 non-null    float64
#  9   PLCO2AN   852 non-null    float64
#  10  PLCO2RTA  852 non-null    float64
#  11  TREATED   852 non-null    int64
#  12  NEIGHBOR  852 non-null    int64
#  13  POST      852 non-null    int64
# dtypes: float64(6), int64(5), object(3)
# memory usage: 93.3+ KB

# %%
plant_data
# Out:
#      ORISPL  YEAR PSTATABB  NAMEPCAP  CAPFAC            SECTOR PLFUELCT  \
# 0     55279  2020       IL    1086.2  0.0808       IPP Non-CHP      GAS
# 1     55296  2020       IL     312.8  0.0053       IPP Non-CHP      GAS
# 2     55188  2020       IL     611.2  0.3719       IPP Non-CHP      GAS
# 3     55253  2020       IL     356.0  0.0122       IPP Non-CHP      GAS
# 4     55438  2020       IL     540.0  0.0800       IPP Non-CHP      GAS
# ..      ...   ...      ...       ...     ...               ...      ...
# 847    3948  2021       WV    1632.6  0.3335  Electric Utility     COAL
# 848    3954  2021       WV    1680.9  0.3741  Electric Utility     COAL
# 849    6264  2021       WV    1300.0  0.6263  Electric Utility     COAL
# 850   55349  2021       WV     344.0  0.4156       IPP Non-CHP      GAS
# 851    6004  2021       WV    1368.0  0.6328       IPP Non-CHP     COAL
#
#       PLNGENAN     PLHTIAN    PLCO2AN  PLCO2RTA  TREATED  NEIGHBOR  POST
# ...
